# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import statistics as stat

# %%
df=pd.DataFrame

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# 1. How many males and females participated in the test

# %%
df["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# 518 females and 482 males participated in the test.

# %% [markdown]
# 2.what do you think about the students parental level of education?

# %%
sns.histplot(df["parental level of education"],kde=True)
plt.xticks(rotation=60)
plt.plot()
# Out:
# []

# %%
df["parental level of education"].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
"""
 59 parents holds masters degree,118 parents holds bachelors degree,
 179 parents studeiedd upto some high school,196 studeied upto high school, 
 222 holds associate's degree and 226 studied upto some collge
 """
# Out:
# "\n 59 parents holds masters degree,118 parents holds bachelors degree,\n 179 parents studeiedd upto some high school,196 studeied upto high school, \n 222 holds associate's degree and 226 studied upto some collge\n "

# %% [markdown]
# 3. who scores the most on average for math , reading and writing based on
# i)  Gender
# ii) Test preperation course

# %%
df.head(1)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10

# %%
df.groupby(["gender","test preparation course"])

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9864\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# math score       66.001
# reading score    69.195
# writing score    68.119
# dtype: float64

# %%
#1.most on average for math,reading and writing based on gender

# %%
df1=df.groupby("gender").mean()
df1
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
df1.max()
# Out:
# math score       68.821577
# reading score    72.590734
# writing score    72.467181
# dtype: float64

# %%
#2.most on average for math,reading and writing based on test preperation course

# %%
df2=df.groupby("test preparation course").mean()
df2
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
df2.max()
# Out:
# math score       69.966480
# reading score    74.175978
# writing score    74.684358
# dtype: float64

# %% [markdown]
# 4.What do you think about the scoring variation for math , reading and writing based on
# i)  Gender
# ii) Test preperation course

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#1. scoring variation based for math, reading and writing based on gender

# %%
df3=df[["gender","math score","reading score","writing score"]]

# %%
df3
# Out:
#      gender  math score  reading score  writing score
# 0    female           0             17             10
# 1    female           8             24             23
# 2    female          18             32             28
# 3    female          11             38             32
# 4    female          22             39             33
# ..      ...         ...            ...            ...
# 995    male          99             87             81
# 996    male         100             96             86
# 997    male         100             97             99
# 998    male         100            100             93
# 999    male         100            100            100
#
# [1000 rows x 4 columns]

# %%
df3.groupby("gender").var()
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
#2. scoring variation based for math, reading and writing based on test preperation course

# %%
df4=df[["test preparation course","math score","reading score","writing score"]]

# %%
df4
# Out:
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
# [1000 rows x 4 columns]

# %%
df4.groupby("test preparation course")
df4
# Out:
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
# [1000 rows x 4 columns]

# %%
df4.var()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9864\1233888712.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.var()
# math score       242.411410
# reading score    216.279254
# writing score    231.842682
# dtype: float64

# %% [markdown]
# 5. The management needs your help to give bonus point to the top 25% of students based on their math score,
# so how will you help the management to achieve this.

# %%
df5=df.sort_values(by="math score",ascending=False)

# %%
df5
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
n = 250
df5.head(int(len(df)*(n/1000)))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
"""
find the top 25% students based on their maths score,which is out of 100. 
since 25% of 1000 students=250, so the management
need to give bonus points to the top 250 students.
"""
